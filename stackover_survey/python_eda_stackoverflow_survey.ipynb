# %%
# Jovian Commit Essentials
# Please retain and execute this cell without modifying the contents for `jovian.commit` to work
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('python-eda-stackoverflow-survey')
jovian.set_colab_id('1k1Uqv5smgrUNTFQRobw1wQUxvJUncRQ8')

# %% [markdown]
# # Exploratory Data Analysis using Python - A Case Study
#
# *Analyzing responses from the Stack Overflow Annual Developer Survey 2020*
#
# ![](https://i.imgur.com/qXhHKqv.png)
#
# ### Part 9 of "Data Analysis with Python: Zero to Pandas"
#
# This tutorial series is a beginner-friendly introduction to programming and data analysis using the Python programming language. These tutorials take a practical and coding-focused approach. The best way to learn the material is to execute the code and experiment with it yourself. Check out the full series here:
#
# 1. [First Steps with Python and Jupyter](https://jovian.ai/aakashns/first-steps-with-python)
# 2. [A Quick Tour of Variables and Data Types](https://jovian.ai/aakashns/python-variables-and-data-types)
# 3. [Branching using Conditional Statements and Loops](https://jovian.ai/aakashns/python-branching-and-loops)
# 4. [Writing Reusable Code Using Functions](https://jovian.ai/aakashns/python-functions-and-scope)
# 5. [Reading from and Writing to Files](https://jovian.ai/aakashns/python-os-and-filesystem)
# 6. [Numerical Computing with Python and Numpy](https://jovian.ai/aakashns/python-numerical-computing-with-numpy)
# 7. [Analyzing Tabular Data using Pandas](https://jovian.ai/aakashns/python-pandas-data-analysis)
# 8. [Data Visualization using Matplotlib & Seaborn](https://jovian.ai/aakashns/python-matplotlib-data-visualization)
# 9. [Exploratory Data Analysis - A Case Study](https://jovian.ai/aakashns/python-eda-stackoverflow-survey)

# %% [markdown]
# The following topics are covered in this tutorial:
#
# - Selecting and downloading a dataset
# - Data preparation and cleaning
# - Exploratory analysis and visualization
# - Asking and answering interesting questions
# - Summarizing inferences and drawing conclusions

# %% [markdown]
# ### How to run the code
#
# This tutorial is an executable [Jupyter notebook](https://jupyter.org) hosted on [Jovian](https://www.jovian.ai). You can _run_ this tutorial and experiment with the code examples in a couple of ways: *using free online resources* (recommended) or *on your computer*.
#
# #### Option 1: Running using free online resources (1-click, recommended)
#
# The easiest way to start executing the code is to click the **Run** button at the top of this page and select **Run on Binder**. You can also select "Run on Colab" or "Run on Kaggle", but you'll need to create an account on [Google Colab](https://colab.research.google.com) or [Kaggle](https://kaggle.com) to use these platforms.
#
#
# #### Option 2: Running on your computer locally
#
# To run the code on your computer locally, you'll need to set up [Python](https://www.python.org), download the notebook and install the required libraries. We recommend using the [Conda](https://docs.conda.io/projects/conda/en/latest/user-guide/install/) distribution of Python. Click the **Run** button at the top of this page, select the **Run Locally** option, and follow the instructions.
#
# >  **Jupyter Notebooks**: This tutorial is a [Jupyter notebook](https://jupyter.org) - a document made of _cells_. Each cell can contain code written in Python or explanations in plain English. You can execute code cells and view the results, e.g., numbers, messages, graphs, tables, files, etc., instantly within the notebook. Jupyter is a powerful platform for experimentation and analysis. Don't be afraid to mess around with the code & break things - you'll learn a lot by encountering and fixing errors. You can use the "Kernel > Restart & Clear Output" menu option to clear all outputs and start again from the top.

# %% [markdown]
# ## Introduction
#
# In this tutorial, we'll analyze the StackOverflow developer survey dataset. The dataset contains responses to an annual survey conducted by StackOverflow. You can find the raw data & official analysis here: https://insights.stackoverflow.com/survey.
#
# There are several options for getting the dataset into Jupyter:
#
# - Download the CSV manually and upload it via Jupyter's GUI
# - Use the `urlretrieve` function from the `urllib.request` to download CSV files from a raw URL
# - Use a helper library, e.g., [`opendatasets`](https://github.com/JovianML/opendatasets), which contains a collection of curated datasets and provides a helper function for direct download.
#
# We'll use the `opendatasets` helper library to download the files.

# %%
# !pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od

# %%
od.download('stackoverflow-developer-survey-2020')
# Out:
# Using downloaded and verified file: ./stackoverflow-developer-survey-2020/survey_results_public.csv
# Using downloaded and verified file: ./stackoverflow-developer-survey-2020/survey_results_schema.csv
# Using downloaded and verified file: ./stackoverflow-developer-survey-2020/README.txt

# %% [markdown]
# Let's verify that the dataset was downloaded into the directory `stackoverflow-developer-survey-2020` and retrieve the list of files in the dataset.

# %%
import os

# %%
os.listdir('stackoverflow-developer-survey-2020')
# Out:
# ['README.txt', 'survey_results_schema.csv', 'survey_results_public.csv']

# %% [markdown]
# You can through the downloaded files using the "File" > "Open" menu option in Jupyter. It seems like the dataset contains three files:
#
# - `README.txt` - Information about the dataset
# - `survey_results_schema.csv` - The list of questions, and shortcodes for each question
# - `survey_results_public.csv` - The full list of responses to the questions
#
# Let's load the CSV files using the Pandas library. We'll use the name `survey_raw_df` for the data frame to indicate this is unprocessed data that we might clean, filter, and modify to prepare a data frame ready for analysis.

# %%
import pandas as pd

# %%
survey_raw_df = pd.read_csv('stackoverflow-developer-survey-2020/survey_results_public.csv')

# %%
survey_raw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0       NaN         13  Monthly        NaN            NaN             Germany
# 1       NaN         19      NaN        NaN            NaN      United Kingdom
# 2       NaN         15      NaN        NaN            NaN  Russian Federation
# 3      25.0         18      NaN        NaN            NaN             Albania
# 4      31.0         16      NaN        NaN            NaN       United States
# ...     ...        ...      ...        ...            ...                 ...
# 64456   NaN         16      NaN        NaN            NaN       United States
# 64457   NaN        NaN      NaN        NaN            NaN             Morocco
# 64458   NaN        NaN      NaN        NaN            NaN            Viet Nam
# 64459   NaN        NaN      NaN        NaN            NaN              Poland
# 64460   NaN        NaN      NaN        NaN            NaN               Spain
#
#          CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0       European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1      Pound sterling  ...                         NaN                    NaN
# 2                 NaN  ...  Neither easy nor difficult  Appropriate in length
# 3        Albanian lek  ...                         NaN                    NaN
# 4                 NaN  ...                        Easy              Too short
# ...               ...  ...                         ...                    ...
# 64456             NaN  ...                         NaN                    NaN
# 64457             NaN  ...                         NaN                    NaN
# 64458             NaN  ...                         NaN                    NaN
# 64459             NaN  ...                         NaN                    NaN
# 64460             NaN  ...                         NaN                    NaN
#
#       Trans                                     UndergradMajor  \
# 0        No  Computer science, computer engineering, or sof...
# 1       NaN  Computer science, computer engineering, or sof...
# 2       NaN                                                NaN
# 3        No  Computer science, computer engineering, or sof...
# 4        No  Computer science, computer engineering, or sof...
# ...     ...                                                ...
# 64456   NaN  Computer science, computer engineering, or sof...
# 64457   NaN                                                NaN
# 64458   NaN                                                NaN
# 64459   NaN                                                NaN
# 64460   NaN  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 0                     ASP.NET Core                    ASP.NET;ASP.NET Core
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4             Django;Ruby on Rails                           Ruby on Rails
# ...                            ...                                     ...
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                   WelcomeChange WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year        50.0        36
# 1      Somewhat more welcome now than last year         NaN         7
# 2      Somewhat more welcome now than last year         NaN         4
# 3      Somewhat less welcome now than last year        40.0         7
# 4       Just as welcome now as I felt last year         NaN        15
# ...                                         ...         ...       ...
# 64456                                       NaN         NaN        10
# 64457                                       NaN         NaN       NaN
# 64458                                       NaN         NaN       NaN
# 64459                                       NaN         NaN       NaN
# 64460                                       NaN         NaN       NaN
#
#            YearsCodePro
# 0                    27
# 1                     4
# 2                   NaN
# 3                     4
# 4                     8
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %% [markdown]
# The dataset contains over 64,000 responses to 60 questions (although many questions are optional). The responses have been anonymized to remove personally identifiable information, and each respondent has been assigned a randomized respondent ID.
#
# Let's view the list of columns in the data frame.

# %%
survey_raw_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %% [markdown]
# It appears that shortcodes for questions have been used as column names.
#
# We can refer to the schema file to see the full text of each question. The schema file contains only two columns: `Column` and `QuestionText`. We can load it as Pandas Series with `Column` as the index and the  `QuestionText` as the value.

# %%
schema_fname = 'stackoverflow-developer-survey-2020/survey_results_schema.csv'
schema_raw = pd.read_csv(schema_fname, index_col='Column').QuestionText

# %%
schema_fname
# Out:
# 'stackoverflow-developer-survey-2020/survey_results_schema.csv'

# %%
schema_raw
# Out:
# Column
# Respondent            Randomized respondent ID number (not in order ...
# MainBranch            Which of the following options best describes ...
# Hobbyist                                        Do you code as a hobby?
# Age                   What is your age (in years)? If you prefer not...
# Age1stCode            At what age did you write your first line of c...
#                                             ...
# WebframeWorkedWith    Which web frameworks have you done extensive d...
# WelcomeChange         Compared to last year, how welcome do you feel...
# WorkWeekHrs           On average, how many hours per week do you wor...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# Name: QuestionText, Length: 61, dtype: object

# %% [markdown]
# We can now use `schema_raw` to retrieve the full question text for any column in `survey_raw_df`.

# %%
schema_raw['YearsCodePro']
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %% [markdown]
# We've now loaded the dataset. We're ready to move on to the next step of preprocessing & cleaning the data for our analysis.

# %% [markdown]
# ### Save and upload your notebook
#
# Whether you're running this Jupyter notebook online or on your computer, it's essential to save your work from time to time. You can continue working on a saved notebook later or share it with friends and colleagues to let them execute your code. [Jovian](https://www.jovian.ai) offers an easy way of saving and sharing your Jupyter notebooks online.

# %%
# Select a project name
project='python-eda-stackoverflow-survey'

# %%
# Install the Jovian library
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
jovian.commit(project=project)
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Uploading colab notebook to Jovian...
# Committed successfully! https://jovian.ai/vijaykumar14198/python-eda-stackoverflow-survey
# 'https://jovian.ai/vijaykumar14198/python-eda-stackoverflow-survey'

# %% [markdown]
# The first time you run `jovian.commit`, you'll be asked to provide an API Key to securely upload the notebook to your Jovian account. You can get the API key from your [Jovian profile page](https://jovian.ai) after logging in / signing up.
#
#
# `jovian.commit` uploads the notebook to your Jovian account, captures the Python environment, and creates a shareable link for your notebook, as shown above. You can use this link to share your work and let anyone (including you) run your notebooks and reproduce your work.

# %% [markdown]
# ## Data Preparation & Cleaning
#
# While the survey responses contain a wealth of information, we'll limit our analysis to the following areas:
#
# - Demographics of the survey respondents and the global programming community
# - Distribution of programming skills, experience, and preferences
# - Employment-related information, preferences, and opinions
#
# Let's select a subset of columns with the relevant data for our analysis.

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
len(selected_columns)
# Out:
# 20

# %% [markdown]
# Let's extract a copy of the data from these columns into a new data frame `survey_df`. We can continue to modify further without affecting the original data frame.

# %%
survey_df = survey_raw_df[selected_columns].copy()

# %%
schema = schema_raw[selected_columns]

# %% [markdown]
# Let's view some basic information about the data frame.

# %%
survey_df.shape
# Out:
# (64461, 20)

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57900 non-null  object
#  7   YearsCode               57684 non-null  object
#  8   YearsCodePro            46349 non-null  object
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
#  14  DevType                 49370 non-null  object
#  15  WorkWeekHrs             41151 non-null  float64
#  16  JobSat                  45194 non-null  object
#  17  JobFactors              49349 non-null  object
#  18  NEWOvertime             43231 non-null  object
#  19  NEWEdImpt               48465 non-null  object
# dtypes: float64(2), object(18)
# memory usage: 9.8+ MB

# %%
schema['YearsCode']
# Out:
# 'Including any education, how many years have you been coding in total?'

# %%
schema['NEWOvertime']
# Out:
# 'How often do you work overtime or beyond the formal time expectation of your job?'

# %%
survey_df['NEWOvertime'].unique()
# Out:
# array(['Often: 1-2 days per week or more', nan,
#        'Occasionally: 1-2 days per quarter but less than monthly',
#        'Never', 'Sometimes: 1-2 days per month but less than weekly',
#        'Rarely: 1-2 days per year or less'], dtype=object)

# %% [markdown]
# Most columns have the data type `object`, either because they contain values of different types or contain empty values (`NaN`). It appears that every column contains some empty values since the Non-Null count for every column is lower than the total number of rows (64461). We'll need to deal with empty values and manually adjust the data type for each column on a case-by-case basis.
#
# Only two of the columns were detected as numeric columns (`Age` and `WorkWeekHrs`), even though a few other columns have mostly numeric values. To make our analysis easier, let's convert some other columns into numeric data types while ignoring any non-numeric value. The non-numeric are converted to `NaN`.

# %%
survey_df['Age1stCode'] = pd.to_numeric(survey_df.Age1stCode, errors='coerce')
survey_df['YearsCode'] = pd.to_numeric(survey_df.YearsCode, errors='coerce')
survey_df['YearsCodePro'] = pd.to_numeric(survey_df.YearsCodePro, errors='coerce')

# %% [markdown]
# Let's now view some basic statistics about numeric columns.

# %%
schema['YearsCodePro']
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %% [markdown]
# There seems to be a problem with the age column, as the minimum value is 1 and the maximum is 279. This is a common issue with surveys: responses may contain invalid values due to accidental or intentional errors while responding. A simple fix would be to ignore the rows where the age is higher than 100 years or lower than 10 years as invalid survey responses. We can do this using the `.drop` method, [as explained here](https://www.geeksforgeeks.org/drop-rows-from-the-dataframe-based-on-certain-condition-applied-on-a-column/).

# %%
survey_df.drop(survey_df[survey_df.Age < 10].index, inplace=True)
survey_df.drop(survey_df[survey_df.Age > 100].index, inplace=True)

# %% [markdown]
# The same holds for `WorkWeekHrs`. Let's ignore entries where the value for the column is higher than 140 hours. (~20 hours per day).

# %%
survey_df.drop(survey_df[survey_df.WorkWeekHrs > 140].index, inplace=True)

# %% [markdown]
# The gender column also allows for picking multiple options. We'll remove values containing more than one option to simplify our analysis.

# %%
survey_df['Gender'].value_counts()
# Out:
# Man                                                            45895
# Woman                                                           3835
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: Gender, dtype: int64

# %%
import numpy as np

# %%
survey_df.where(~(survey_df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %% [markdown]
# We've now cleaned up and prepared the dataset for analysis. Let's take a look at a sample of rows from the data frame.

# %%
survey_df.sample(10)
# Out:
#              Country   Age Gender  \
# 51943         Brazil  22.0    Man
# 51513    Switzerland  34.0    Man
# 17318         France  43.0    Man
# 45309            NaN   NaN    NaN
# 1004         Germany  23.0    Man
# 25043         Brazil  33.0    Man
# 63995          Ghana   NaN    NaN
# 19901  United States  19.0    Man
# 41556         France   NaN    NaN
# 36781         Turkey   NaN    NaN
#
#                                                  EdLevel  \
# 51943       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51513    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 17318    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 45309                                                NaN
# 1004   Secondary school (e.g. American high school, G...
# 25043       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 63995  Secondary school (e.g. American high school, G...
# 19901  Some college/university study without earning ...
# 41556                                                NaN
# 36781                                                NaN
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 51943  Computer science, computer engineering, or sof...      Yes        17.0
# 51513  Another engineering discipline (such as civil,...      Yes        14.0
# 17318  Computer science, computer engineering, or sof...      Yes        10.0
# 45309                                                NaN      NaN         NaN
# 1004                                                 NaN      Yes        10.0
# 25043  Computer science, computer engineering, or sof...      Yes        11.0
# 63995                                                NaN       No        12.0
# 19901  Computer science, computer engineering, or sof...      Yes        13.0
# 41556                                                NaN      Yes         NaN
# 36781                                                NaN      Yes         NaN
#
#        YearsCode  YearsCodePro  \
# 51943        5.0           4.0
# 51513       18.0          15.0
# 17318       33.0          33.0
# 45309        NaN           NaN
# 1004        10.0           4.0
# 25043       14.0          12.0
# 63995       10.0          10.0
# 19901        7.0           3.0
# 41556        NaN           NaN
# 36781        NaN           NaN
#
#                                       LanguageWorkedWith  \
# 51943  C#;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 51513                                  C;C++;Python;Rust
# 17318          Bash/Shell/PowerShell;C;HTML/CSS;Java;SQL
# 45309                                                NaN
# 1004                             C++;Go;HTML/CSS;PHP;SQL
# 25043                       HTML/CSS;JavaScript;Ruby;SQL
# 63995     Dart;HTML/CSS;JavaScript;Python;SQL;TypeScript
# 19901  Assembly;Bash/Shell/PowerShell;C;C++;Haskell;H...
# 41556                                           C;C#;C++
# 36781                                                NaN
#
#                                   LanguageDesireNextYear  \
# 51943  C#;Dart;Go;HTML/CSS;Java;JavaScript;SQL;TypeSc...
# 51513                                        Kotlin;Rust
# 17318                  Bash/Shell/PowerShell;C;Java;Rust
# 45309                                                NaN
# 1004                             C++;Go;HTML/CSS;PHP;SQL
# 25043                       HTML/CSS;JavaScript;Ruby;SQL
# 63995     Dart;HTML/CSS;JavaScript;Python;SQL;TypeScript
# 19901            Assembly;C;Go;Haskell;Python;Rust;Scala
# 41556             Go;HTML/CSS;Java;JavaScript;TypeScript
# 36781                                                NaN
#
#                    NEWLearn  \
# 51943      Every few months
# 51513      Every few months
# 17318  Once every few years
# 45309                   NaN
# 1004            Once a year
# 25043  Once every few years
# 63995  Once every few years
# 19901      Every few months
# 41556           Once a year
# 36781      Every few months
#
#                                                 NEWStuck  \
# 51943  Visit Stack Overflow;Watch help / tutorial vid...
# 51513  Call a coworker or friend;Watch help / tutoria...
# 17318  Play games;Call a coworker or friend;Visit Sta...
# 45309                                                NaN
# 1004   Call a coworker or friend;Visit Stack Overflow...
# 25043                               Visit Stack Overflow
# 63995  Play games;Call a coworker or friend;Visit Sta...
# 19901  Meditate;Play games;Call a coworker or friend;...
# 41556  Call a coworker or friend;Visit Stack Overflow...
# 36781                                                NaN
#
#                                               Employment  \
# 51943                                 Employed full-time
# 51513                                 Employed part-time
# 17318                                 Employed full-time
# 45309                                                NaN
# 1004                                  Employed full-time
# 25043                                 Employed full-time
# 63995                                 Employed full-time
# 19901                                 Employed full-time
# 41556                                 Employed full-time
# 36781  Independent contractor, freelancer, or self-em...
#
#                                                  DevType  WorkWeekHrs  \
# 51943  Developer, back-end;Developer, desktop or ente...         40.0
# 51513  Developer, desktop or enterprise applications;...         38.0
# 17318  Data scientist or machine learning specialist;...         50.0
# 45309                                                NaN          NaN
# 1004   Database administrator;Designer;Developer, bac...         40.0
# 25043  Developer, back-end;Developer, front-end;Devel...         40.0
# 63995  Developer, back-end;Developer, front-end;Devel...         40.0
# 19901  Developer, back-end;Developer, embedded applic...         45.0
# 41556                                                NaN          NaN
# 36781                                                NaN          NaN
#
#                                    JobSat  \
# 51943  Neither satisfied nor dissatisfied
# 51513                   Very dissatisfied
# 17318                      Very satisfied
# 45309                                 NaN
# 1004   Neither satisfied nor dissatisfied
# 25043                  Slightly satisfied
# 63995                  Slightly satisfied
# 19901                      Very satisfied
# 41556                                 NaN
# 36781                                 NaN
#
#                                               JobFactors  \
# 51943  Flex time or a flexible schedule;Languages, fr...
# 51513  Industry that I’d be working in;How widely use...
# 17318  Flex time or a flexible schedule;Remote work o...
# 45309                                                NaN
# 1004   Flex time or a flexible schedule;Financial per...
# 25043  Languages, frameworks, and other technologies ...
# 63995  Remote work options;Financial performance or f...
# 19901  Languages, frameworks, and other technologies ...
# 41556                                                NaN
# 36781                                                NaN
#
#                                              NEWOvertime  \
# 51943  Sometimes: 1-2 days per month but less than we...
# 51513                  Rarely: 1-2 days per year or less
# 17318                   Often: 1-2 days per week or more
# 45309                                                NaN
# 1004   Sometimes: 1-2 days per month but less than we...
# 25043  Occasionally: 1-2 days per quarter but less th...
# 63995  Occasionally: 1-2 days per quarter but less th...
# 19901                   Often: 1-2 days per week or more
# 41556                                                NaN
# 36781                                                NaN
#
#                                 NEWEdImpt
# 51943                    Fairly important
# 51513                      Very important
# 17318                      Very important
# 45309                                 NaN
# 1004                   Somewhat important
# 25043                Critically important
# 63995  Not at all important/not necessary
# 19901                    Fairly important
# 41556                                 NaN
# 36781                                 NaN

# %% [markdown]
# Let's save and commit our work before continuing.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Detected Colab notebook...
# [jovian] Uploading colab notebook to Jovian...
# Committed successfully! https://jovian.ai/vijaykumar14198/python-eda-stackoverflow-survey
# 'https://jovian.ai/vijaykumar14198/python-eda-stackoverflow-survey'

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# Before we ask questions about the survey responses, it would help to understand the respondents' demographics, i.e., country, age, gender, education level, employment level, etc. It's essential to explore these variables to understand how representative the survey is of the worldwide programming community. A survey of this scale generally tends to have some [selection bias](https://en.wikipedia.org/wiki/Selection_bias).
#
# Let's begin by importing `matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ### Country
#
# Let's look at the number of countries from which there are responses in the survey and plot the ten countries with the highest number of responses.

# %%
schema.Country
# Out:
# 'Where do you live?'

# %%
survey_df.Country.nunique()
# Out:
# 183

# %% [markdown]
# We can identify the countries with the highest number of respondents using the `value_counts` method.

# %%
top_countries = survey_df.Country.value_counts().head(15)
top_countries
# Out:
# United States         12371
# India                  8364
# United Kingdom         3881
# Germany                3864
# Canada                 2175
# France                 1884
# Brazil                 1804
# Netherlands            1332
# Poland                 1259
# Australia              1199
# Spain                  1157
# Italy                  1115
# Russian Federation     1085
# Sweden                  879
# Pakistan                802
# Name: Country, dtype: int64

# %% [markdown]
# We can visualize this information using a bar chart.

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
plt.title(schema.Country)
sns.barplot(x=top_countries.index, y=top_countries);

# %% [markdown]
# It appears that a disproportionately high number of respondents are from the US and India, probably because the survey is in English, and these countries have the highest English-speaking populations. We can already see that the survey may not be representative of the global programming community - especially from non-English speaking countries. Programmers from non-English speaking countries are almost certainly underrepresented.
#
# **Exercise**:
# Try finding the percentage of responses from English-speaking vs. non-English speaking countries. You can use [this list of languages spoken in different countries](https://github.com/JovianML/opendatasets/blob/master/data/countries-languages-spoken/countries-languages.csv).

# %% [markdown]
# ### Age
#
# The distribution of respondents' age is another crucial factor to look at. We can use a histogram to visualize it.

# %%
plt.figure(figsize=(12, 6))
plt.title(schema.Age)
plt.xlabel('Age')
plt.ylabel('Number of respondents')

plt.hist(survey_df.Age, bins=np.arange(10,80,5), color='purple');

# %% [markdown]
# It appears that a large percentage of respondents are 20-45 years old. It's somewhat representative of the programming community in general. Many young people have taken up computer science as their field of study or profession in the last 20 years.
#
# **Exercise**: You may want to filter out responses by age (or age group) if you'd like to analyze and compare the survey results for different age groups. Create a new column called AgeGroup containing values like `Less than 10 years`, `10-18 years`, `18-30 years`, `30-45 years`, `45-60 years` and `Older than 60 years`. Then, repeat the analysis in the rest of this notebook for each age group.

# %% [markdown]
# Excercise solution .....

# %%
survey_df.columns
# Out:
# Index(['Country', 'Age', 'Gender', 'EdLevel', 'UndergradMajor', 'Hobbyist',
#        'Age1stCode', 'YearsCode', 'YearsCodePro', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'NEWLearn', 'NEWStuck', 'Employment',
#        'DevType', 'WorkWeekHrs', 'JobSat', 'JobFactors', 'NEWOvertime',
#        'NEWEdImpt'],
#       dtype='object')

# %%
ageGroup=[] ## empty list so we add elements according to condition

groups=['Less than 10 years','10-18 years','18-30 years','30-45 years','45-60 years','Older than 60 years'] # what we want add

# function to fill list ageGroup according to condition 
def age_group():
  for age in survey_df['Age']:
    if age<10:
      ageGroup.append("Less than 10 years")
    elif age>=10 and age<18:
      ageGroup.append('10-18 years')
    elif age>=18 and age<30:
      ageGroup.append('18-30 years')
    elif age>=30 and age<45:
      ageGroup.append('30-45 years')
    elif age>=45 and age<60:
      ageGroup.append('45-60 years')
    elif age>=60:
      ageGroup.append('Older than 60 years')
    else:
      ageGroup.append("NaN")

# %%
age_group()# calling function

# %%
survey_df['ageGroup']=ageGroup # adding new column in dataset

# %%
survey_df.sample(15)
# Out:
#               Country   Age Gender  \
# 22216  United Kingdom   NaN    Man
# 63342          Uganda   NaN    NaN
# 15835         Germany  28.0    Man
# 55527          France  27.0    Man
# 20457   United States  43.0    Man
# 35536          Norway  37.0    Man
# 50004           Kenya  26.0    Man
# 40527           India   NaN    NaN
# 24814   United States  21.0    Man
# 690     United States  54.0    Man
# 55410           Sudan  26.0    Man
# 56147    South Africa  40.0    Man
# 61528          Serbia   NaN    NaN
# 3610           Norway   NaN    Man
# 12417         Morocco  35.0    Man
#
#                                                  EdLevel  \
# 22216    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 63342                                                NaN
# 15835    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 55527                 Professional degree (JD, MD, etc.)
# 20457    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 35536  Secondary school (e.g. American high school, G...
# 50004                Associate degree (A.A., A.S., etc.)
# 40527    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 24814       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 690      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 55410       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 56147       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 61528       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3610        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12417                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 22216  Information systems, information technology, o...       No        25.0
# 63342                                                NaN      Yes         NaN
# 15835  Computer science, computer engineering, or sof...      Yes        19.0
# 55527                      Web development or web design      Yes        18.0
# 20457  Another engineering discipline (such as civil,...      Yes        15.0
# 35536                                                NaN      Yes        14.0
# 50004                      Web development or web design       No        14.0
# 40527  Computer science, computer engineering, or sof...       No        21.0
# 24814  A natural science (such as biology, chemistry,...      Yes        16.0
# 690                                                  NaN       No        14.0
# 55410  Information systems, information technology, o...      Yes        20.0
# 56147  Computer science, computer engineering, or sof...       No        15.0
# 61528  Computer science, computer engineering, or sof...      Yes        19.0
# 3610   Computer science, computer engineering, or sof...      Yes        13.0
# 12417  Information systems, information technology, o...       No         5.0
#
#        YearsCode  YearsCodePro  \
# 22216       25.0          25.0
# 63342        NaN           NaN
# 15835        9.0           6.0
# 55527        8.0           5.0
# 20457       26.0          22.0
# 35536       13.0          18.0
# 50004        4.0           NaN
# 40527       12.0           7.0
# 24814        3.0           1.0
# 690         30.0          20.0
# 55410        6.0           4.0
# 56147       25.0          19.0
# 61528        4.0           2.0
# 3610        23.0          19.0
# 12417        1.0           1.0
#
#                                       LanguageWorkedWith  ...  \
# 22216                            HTML/CSS;JavaScript;SQL  ...
# 63342                                                NaN  ...
# 15835                                        Java;Kotlin  ...
# 55527                        HTML/CSS;JavaScript;PHP;SQL  ...
# 20457                                         Python;SQL  ...
# 35536  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...  ...
# 50004                     HTML/CSS;JavaScript;TypeScript  ...
# 40527                                                NaN  ...
# 24814   C;C++;HTML/CSS;JavaScript;Julia;PHP;Python;R;SQL  ...
# 690                           Java;JavaScript;Python;SQL  ...
# 55410                         C;HTML/CSS;Java;Python;SQL  ...
# 56147                                          C#;Python  ...
# 61528  C#;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript  ...
# 3610                                                 NaN  ...
# 12417                            Assembly;C;Java;SQL;VBA  ...
#
#                    NEWLearn  \
# 22216  Once every few years
# 63342                   NaN
# 15835  Once every few years
# 55527  Once every few years
# 20457           Once a year
# 35536           Once a year
# 50004           Once a year
# 40527                   NaN
# 24814      Every few months
# 690        Every few months
# 55410           Once a year
# 56147  Once every few years
# 61528           Once a year
# 3610   Once every few years
# 12417           Once a year
#
#                                                 NEWStuck  \
# 22216  Call a coworker or friend;Visit Stack Overflow...
# 63342                                                NaN
# 15835     Call a coworker or friend;Visit Stack Overflow
# 55527  Call a coworker or friend;Visit Stack Overflow...
# 20457  Call a coworker or friend;Visit Stack Overflow...
# 35536  Play games;Visit Stack Overflow;Go for a walk ...
# 50004  Play games;Go for a walk or other physical act...
# 40527                                                NaN
# 24814  Meditate;Visit Stack Overflow;Watch help / tut...
# 690                                 Visit Stack Overflow
# 55410  Call a coworker or friend;Visit Stack Overflow...
# 56147  Call a coworker or friend;Visit Stack Overflow...
# 61528  Visit Stack Overflow;Go for a walk or other ph...
# 3610   Visit Stack Overflow;Go for a walk or other ph...
# 12417  Go for a walk or other physical activity;Watch...
#
#                                               Employment  \
# 22216                                 Employed full-time
# 63342                                            Student
# 15835                                 Employed full-time
# 55527                                 Employed full-time
# 20457                                 Employed full-time
# 35536                                 Employed full-time
# 50004                                            Student
# 40527                                 Employed full-time
# 24814  Independent contractor, freelancer, or self-em...
# 690                                   Employed full-time
# 55410                                 Employed full-time
# 56147                                 Employed full-time
# 61528                                 Employed full-time
# 3610                                  Employed full-time
# 12417                                 Employed full-time
#
#                                                  DevType WorkWeekHrs  \
# 22216                              Developer, full-stack        39.0
# 63342                                                NaN         NaN
# 15835                                  Developer, mobile        40.0
# 55527  Developer, back-end;Developer, front-end;Devel...        40.0
# 20457                                Senior executive/VP         NaN
# 35536  Developer, back-end;Developer, full-stack;DevO...        40.0
# 50004                                                NaN         NaN
# 40527                                  Developer, mobile        40.0
# 24814  Data or business analyst;Data scientist or mac...        20.0
# 690        Data scientist or machine learning specialist        40.0
# 55410      Developer, desktop or enterprise applications        40.0
# 56147  Developer, back-end;Developer, desktop or ente...        45.0
# 61528  Data scientist or machine learning specialist;...         NaN
# 3610                                Developer, front-end         NaN
# 12417  Academic researcher;Data or business analyst;D...         NaN
#
#                       JobSat  \
# 22216     Slightly satisfied
# 63342                    NaN
# 15835     Slightly satisfied
# 55527     Slightly satisfied
# 20457                    NaN
# 35536         Very satisfied
# 50004                    NaN
# 40527  Slightly dissatisfied
# 24814         Very satisfied
# 690    Slightly dissatisfied
# 55410         Very satisfied
# 56147  Slightly dissatisfied
# 61528     Slightly satisfied
# 3610          Very satisfied
# 12417                    NaN
#
#                                               JobFactors  \
# 22216  Industry that I’d be working in;Flex time or a...
# 63342                                                NaN
# 15835  Specific department or team I’d be working on;...
# 55527  Languages, frameworks, and other technologies ...
# 20457                                                NaN
# 35536  Flex time or a flexible schedule;Languages, fr...
# 50004  Languages, frameworks, and other technologies ...
# 40527                                                NaN
# 24814  Industry that I’d be working in;Remote work op...
# 690    Flex time or a flexible schedule;Opportunities...
# 55410  Financial performance or funding status of the...
# 56147  Industry that I’d be working in;Languages, fra...
# 61528                                                NaN
# 3610          Opportunities for professional development
# 12417                                                NaN
#
#                                              NEWOvertime  \
# 22216                   Often: 1-2 days per week or more
# 63342                                                NaN
# 15835                                              Never
# 55527  Sometimes: 1-2 days per month but less than we...
# 20457                                                NaN
# 35536  Sometimes: 1-2 days per month but less than we...
# 50004                                                NaN
# 40527  Sometimes: 1-2 days per month but less than we...
# 24814  Sometimes: 1-2 days per month but less than we...
# 690                                                Never
# 55410                   Often: 1-2 days per week or more
# 56147  Occasionally: 1-2 days per quarter but less th...
# 61528                                                NaN
# 3610                   Rarely: 1-2 days per year or less
# 12417                                                NaN
#
#                                 NEWEdImpt     ageGroup
# 22216  Not at all important/not necessary          NaN
# 63342                                 NaN          NaN
# 15835                    Fairly important  18-30 years
# 55527                      Very important  18-30 years
# 20457                      Very important  30-45 years
# 35536                    Fairly important  30-45 years
# 50004                                 NaN  18-30 years
# 40527                      Very important          NaN
# 24814                    Fairly important  18-30 years
# 690                        Very important  45-60 years
# 55410                    Fairly important  18-30 years
# 56147                    Fairly important  30-45 years
# 61528                  Somewhat important          NaN
# 3610                                  NaN          NaN
# 12417                      Very important  30-45 years
#
# [15 rows x 21 columns]

# %%
sns.scatterplot(x='WorkWeekHrs',y="YearsCodePro" , hue='ageGroup', data=survey_df)
plt.xlabel("WorkWeekHrs")
plt.ylabel("Years of professional coding experience");
sns.set(rc={'figure.figsize':(12,6)})

# %% [markdown]
# ### Gender
#
# Let's look at the distribution of responses for the Gender. It's a well-known fact that women and non-binary genders are underrepresented in the programming community, so we might expect to see a skewed distribution here.

# %%
schema.Gender
# Out:
# 'Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
gender_counts = survey_df.Gender.value_counts()
gender_counts
# Out:
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %% [markdown]
# A pie chart would be a great way to visualize the distribution.

# %%
plt.figure(figsize=(12,6))
plt.title(schema.Gender)
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# Only about 8% of survey respondents who have answered the question identify as women or non-binary. This number is lower than the overall percentage of women & non-binary genders in the programming community - which is estimated to be around 12%.
#
# **Exercise**: It would be interesting to compare the survey responses & preferences across genders. Repeat this analysis with these breakdowns. How do the relative education levels differ across genders? How do the salaries vary? You may find this analysis on the [Gender Divide in Data Science](https://medium.com/datadriveninvestor/exploratory-data-analysis-eda-understanding-the-gender-divide-in-data-science-roles-9faa5da44f5b) useful.

# %% [markdown]
# ### Education Level
#
# Formal education in computer science is often considered an essential requirement for becoming a programmer. However, there are many free resources & tutorials available online to learn programming. Let's compare the education levels of respondents to gain some insight into this. We'll use a horizontal bar plot here.

# %%
sns.countplot(y=survey_df.EdLevel)
plt.xticks(rotation=75);
plt.title(schema['EdLevel'])
plt.ylabel(None);

# %% [markdown]
# It appears that well over half of the respondents hold a bachelor's or master's degree, so most programmers seem to have some college education. However, it's not clear from this graph alone if they hold a degree in computer science.
#
# **Exercises**: The graph currently shows the number of respondents for each option. Can you modify it to show the percentage instead? Further, try comparing the percentages for each degree for men vs. women.

# %%
Edlevel_pct = survey_df.EdLevel.value_counts()*100/survey_df.EdLevel.count()


sns.barplot(x= Edlevel_pct,y=Edlevel_pct.index)


plt.title(schema.EdLevel)
plt.ylabel(None)
plt.xlabel("percentage")
# Out:
# Text(0.5, 0, 'percentage')

# %%
survey_df.columns
# Out:
# Index(['Country', 'Age', 'Gender', 'EdLevel', 'UndergradMajor', 'Hobbyist',
#        'Age1stCode', 'YearsCode', 'YearsCodePro', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'NEWLearn', 'NEWStuck', 'Employment',
#        'DevType', 'WorkWeekHrs', 'JobSat', 'JobFactors', 'NEWOvertime',
#        'NEWEdImpt', 'ageGroup'],
#       dtype='object')

# %%
Edlevel_pct = survey_df.EdLevel.value_counts()*100/survey_df.EdLevel.count()


sns.barplot(x=Edlevel_pct,y=Edlevel_pct.index,hue="Gender")


plt.title(schema.EdLevel)
plt.ylabel(None)
plt.xlabel("percentage")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-5fc0ba770b9c> in <module>()
#       2
#       3
# ----> 4 sns.barplot(x=Edlevel_pct,y=Edlevel_pct.index,hue="Gender")
#       5
#       6
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
# -> 3185                           errcolor, errwidth, capsize, dodge)
#    3186
#    3187     if ax is None:
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1583         """Initialize the plotter."""
#    1584         self.establish_variables(x, y, hue, data, orient,
# -> 1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#    1587         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Gender'

# %% [markdown]
# Let's also plot undergraduate majors, but this time we'll convert the numbers into percentages and sort the values to make it easier to visualize the order.

# %%
schema.UndergradMajor
# Out:
# 'What was your primary field of study?'

# %%
undergrad_pct = survey_df.UndergradMajor.value_counts() * 100 / survey_df.UndergradMajor.count()

sns.barplot(x=undergrad_pct, y=undergrad_pct.index)

plt.title(schema.UndergradMajor)
plt.ylabel(None);
plt.xlabel('Percentage');

# %% [markdown]
# It turns out that 40% of programmers holding a college degree have a field of study other than computer science - which is very encouraging. It seems to suggest that while a college education is helpful in general, you do not need to pursue a major in computer science to become a successful programmer.
#
# **Exercises**: Analyze the `NEWEdImpt` column for respondents who hold some college degree vs. those who don't. Do you notice any difference in opinion?

# %%
schema.NEWEdImpt
# Out:
# 'How important is a formal education, such as a university degree in computer science, to your career?'

# %%
survey_df.NEWEdImpt.unique()
# Out:
# array(['Fairly important', nan, 'Not at all important/not necessary',
#        'Very important', 'Somewhat important', 'Critically important'],
#       dtype=object)

# %%
sns.barplot()

# %% [markdown]
# ### Employment
#
# Freelancing or contract work is a common choice among programmers, so it would be interesting to compare the breakdown between full-time, part-time, and freelance work. Let's visualize the data from the `Employment` column.

# %%
schema.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
(survey_df.Employment.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='g') #pandas plot function diff way of ploting function
plt.title(schema.Employment)
plt.xlabel('Percentage');

# %% [markdown]
# It appears that close to 10% of respondents are employed part time or as freelancers.
#
# **Exercise**: Add a new column `EmploymentType` containing the values `Enthusiast` (student or not employed but looking for work), `Professional` (employed full-time, part-time or freelancing), and `Other` (not employed or retired). For each of the graphs that follow, show a comparison between `Enthusiast` and `Professional`.

# %%
survey_df.Employment.nunique()
# Out:
# 7

# %%
survey_df.Employment.unique()
# Out:
# array(['Independent contractor, freelancer, or self-employed',
#        'Employed full-time', nan, 'Student',
#        'Not employed, but looking for work', 'Employed part-time',
#        'Retired', 'Not employed, and not looking for work'], dtype=object)

# %% [markdown]
# The `DevType` field contains information about the roles held by respondents. Since the question allows multiple answers, the column contains lists of values separated by a semi-colon `;`, making it a bit harder to analyze directly.

# %%
schema.DevType
# Out:
# 'Which of the following describe you? Please select all that apply.'

# %%
survey_df.DevType.value_counts()
# Out:
# Developer, full-stack                                                                                                                                                           4396
# Developer, back-end                                                                                                                                                             3056
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                  2214
# Developer, back-end;Developer, full-stack                                                                                                                                       1465
# Developer, front-end                                                                                                                                                            1390
#                                                                                                                                                                                 ...
# Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, QA or test;Senior executive/VP                                                    1
# Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Product manager;Senior executive/VP                                                          1
# Developer, back-end;Developer, full-stack;Developer, mobile;DevOps specialist;Educator;System administrator                                                                        1
# Data or business analyst;Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, mobile;Engineering manager       1
# Data or business analyst;Developer, mobile;Senior executive/VP;System administrator                                                                                                1
# Name: DevType, Length: 8213, dtype: int64

# %% [markdown]
# Let's define a helper function that turns a column containing lists of values (like `survey_df.DevType`) into a data frame with one column for each possible option.

# %%
type(survey_df.DevType)
# Out:
# pandas.core.series.Series

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    print("result_df:",result_df)
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].iteritems():
        print("idx:",idx)
        print("value:",value)
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
survey_df['DevType'][0]
# Out:
# 'Developer, desktop or enterprise applications;Developer, full-stack'

# %%
dev_type_df = split_multicolumn(survey_df.DevType)
# Out:
# Streaming output truncated to the last 5000 lines.
# idx: 12291
# value: Database administrator;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;Educator;Engineer, data;Engineer, site reliability;Product manager;System administrator
# idx: 12292
# value: Developer, desktop or enterprise applications
# idx: 12293
# value: Developer, QA or test
# idx: 12294
# value: Developer, back-end;Developer, front-end
# idx: 12295
# value: Developer, back-end
# idx: 12296
# value: Senior executive/VP
# idx: 12297
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12299
# value: Designer;Developer, front-end
# idx: 12300
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices
# idx: 12301
# value: Developer, back-end;DevOps specialist;System administrator
# idx: 12303
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12304
# value: Database administrator;Designer;Developer, back-end;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;DevOps specialist;Educator;System administrator
# idx: 12305
# value: Developer, full-stack;Developer, mobile;DevOps specialist;System administrator
# idx: 12306
# value: Data or business analyst;Data scientist or machine learning specialist;Database administrator;Developer, desktop or enterprise applications;Engineer, data
# idx: 12308
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12309
# value: Database administrator;Developer, back-end
# idx: 12310
# value: Developer, full-stack;DevOps specialist
# idx: 12311
# value: Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist;Engineer, site reliability
# idx: 12312
# value: Academic researcher;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12314
# value: Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile;Marketing or sales professional;System administrator
# idx: 12316
# value: Data or business analyst;Database administrator;Developer, full-stack;Developer, mobile;System administrator
# idx: 12317
# value: Developer, back-end;Developer, desktop or enterprise applications;Engineering manager
# idx: 12318
# value: Developer, game or graphics
# idx: 12320
# value: Data or business analyst;Developer, desktop or enterprise applications
# idx: 12321
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile;Engineer, data
# idx: 12323
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 12324
# value: Data scientist or machine learning specialist;Developer, back-end
# idx: 12325
# value: Developer, back-end;Developer, full-stack
# idx: 12328
# value: Educator
# idx: 12329
# value: Developer, desktop or enterprise applications;Developer, full-stack;Developer, mobile
# idx: 12330
# value: Developer, back-end;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile;Developer, QA or test
# idx: 12331
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack;Developer, game or graphics;System administrator
# idx: 12332
# value: Developer, full-stack
# idx: 12333
# value: Developer, full-stack
# idx: 12334
# value: Developer, back-end;Developer, full-stack;Developer, mobile
# idx: 12335
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile;DevOps specialist;System administrator
# idx: 12336
# value: Educator
# idx: 12337
# value: Database administrator;Designer;Developer, back-end;Developer, front-end
# idx: 12340
# value: Developer, mobile
# idx: 12341
# value: System administrator
# idx: 12342
# value: Developer, back-end;Developer, full-stack
# idx: 12343
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12344
# value: Developer, back-end;Developer, full-stack
# idx: 12345
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12347
# value: Academic researcher;Database administrator;Designer;Developer, full-stack;Developer, QA or test
# idx: 12348
# value: Developer, desktop or enterprise applications
# idx: 12349
# value: Developer, back-end;Developer, full-stack
# idx: 12350
# value: Data or business analyst;Data scientist or machine learning specialist;Developer, back-end
# idx: 12351
# value: Academic researcher;Data or business analyst;Database administrator;Scientist
# idx: 12352
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile;Developer, QA or test;DevOps specialist;Engineer, data;Engineer, site reliability;System administrator
# idx: 12353
# value: Developer, back-end;Developer, full-stack
# idx: 12354
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile;Engineer, data
# idx: 12355
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12356
# value: Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist
# idx: 12357
# value: Developer, back-end;Developer, full-stack
# idx: 12359
# value: Developer, back-end
# idx: 12360
# value: Developer, back-end
# idx: 12361
# value: Developer, front-end;Developer, full-stack
# idx: 12362
# value: Developer, full-stack
# idx: 12363
# value: Data or business analyst;Database administrator;Designer
# idx: 12364
# value: Developer, back-end;System administrator
# idx: 12366
# value: Designer;Educator
# idx: 12368
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Engineering manager
# idx: 12369
# value: Developer, desktop or enterprise applications;Developer, front-end;Developer, game or graphics
# idx: 12370
# value: Developer, full-stack;Engineer, data;Engineer, site reliability;System administrator
# idx: 12371
# value: Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Educator
# idx: 12372
# value: Developer, full-stack
# idx: 12373
# value: Developer, back-end;DevOps specialist;System administrator
# idx: 12375
# value: Academic researcher;Developer, back-end;Developer, desktop or enterprise applications
# idx: 12376
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 12377
# value: Designer;Developer, game or graphics
# idx: 12378
# value: Academic researcher;Developer, game or graphics
# idx: 12379
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12382
# value: Academic researcher;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;Educator
# idx: 12383
# value: Academic researcher;Designer;Developer, game or graphics;Scientist
# idx: 12384
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, mobile
# idx: 12385
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12386
# value: Developer, full-stack
# idx: 12387
# value: Academic researcher;Data or business analyst;Developer, back-end;Developer, front-end;Developer, mobile;Engineer, data
# idx: 12388
# value: Engineer, data
# idx: 12390
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices
# idx: 12391
# value: Developer, front-end;Developer, full-stack
# idx: 12392
# value: Developer, full-stack
# idx: 12393
# value: Database administrator;Engineer, data
# idx: 12394
# value: Developer, back-end;System administrator
# idx: 12395
# value: Data or business analyst;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile;Product manager
# idx: 12396
# value: Data or business analyst;Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile;Developer, QA or test;System administrator
# idx: 12397
# value: Academic researcher;Data scientist or machine learning specialist;Developer, back-end;Developer, desktop or enterprise applications
# idx: 12398
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12399
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 12400
# value: Academic researcher;Database administrator;Developer, embedded applications or devices;Engineer, data;Engineering manager;System administrator
# idx: 12401
# value: Developer, back-end;Developer, full-stack
# idx: 12402
# value: Developer, back-end
# idx: 12403
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile;Developer, QA or test;DevOps specialist;Educator
# idx: 12404
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack;Developer, mobile
# idx: 12406
# value: Designer;Developer, front-end
# idx: 12408
# value: Developer, QA or test;DevOps specialist
# idx: 12409
# value: Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;Developer, back-end;Developer, full-stack;Engineer, data;System administrator
# idx: 12410
# value: Engineer, data
# idx: 12411
# value: Developer, full-stack
# idx: 12412
# value: Developer, back-end
# idx: 12413
# value: Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist
# idx: 12414
# value: Developer, full-stack
# idx: 12415
# value: Database administrator;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12416
# value: Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12417
# value: Academic researcher;Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile;Developer, QA or test;DevOps specialist;Educator;Engineer, data;Engineer, site reliability;Engineering manager;Marketing or sales professional;Product manager;Scientist;Senior executive/VP;System administrator
# idx: 12418
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, game or graphics
# idx: 12419
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12420
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, QA or test;DevOps specialist
# idx: 12421
# value: Academic researcher;Developer, back-end;Developer, front-end;Developer, mobile;Developer, QA or test;Educator;Scientist
# idx: 12422
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12423
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile;DevOps specialist
# idx: 12424
# value: Developer, back-end;Developer, full-stack
# idx: 12425
# value: Developer, back-end;Developer, desktop or enterprise applications;DevOps specialist
# idx: 12426
# value: Academic researcher;Data or business analyst;Data scientist or machine learning specialist;Developer, full-stack
# idx: 12427
# value: Developer, full-stack
# idx: 12428
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack;DevOps specialist;System administrator
# idx: 12429
# value: Developer, back-end;Developer, full-stack
# idx: 12430
# value: Academic researcher;Developer, back-end;Developer, desktop or enterprise applications;Developer, game or graphics;Developer, mobile;Educator
# idx: 12432
# value: Data or business analyst;Database administrator;Designer;Developer, desktop or enterprise applications;Developer, mobile;Engineer, data;Engineering manager;System administrator
# idx: 12433
# value: Database administrator;Designer;Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12434
# value: Developer, front-end
# idx: 12435
# value: Developer, back-end;System administrator
# idx: 12437
# value: Developer, back-end;Developer, full-stack;Developer, mobile
# idx: 12439
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, QA or test;DevOps specialist;Engineer, site reliability
# idx: 12441
# value: Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12442
# value: Developer, back-end;Developer, full-stack;Engineer, site reliability
# idx: 12443
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12445
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12446
# value: Data scientist or machine learning specialist
# idx: 12447
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Educator;Scientist
# idx: 12448
# value: Developer, desktop or enterprise applications
# idx: 12449
# value: Database administrator;Developer, back-end;Developer, full-stack;Product manager
# idx: 12450
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile;Senior executive/VP
# idx: 12451
# value: Academic researcher;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, game or graphics;Educator;Engineer, data;Engineering manager;Product manager;Scientist
# idx: 12452
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12453
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12454
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Product manager;System administrator
# idx: 12455
# value: Developer, front-end
# idx: 12456
# value: Data or business analyst;Developer, back-end;Engineer, data
# idx: 12457
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 12459
# value: Developer, full-stack
# idx: 12461
# value: Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, full-stack;Developer, mobile;System administrator
# idx: 12464
# value: Developer, back-end;Developer, full-stack;DevOps specialist
# idx: 12465
# value: Designer;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile
# idx: 12466
# value: Developer, front-end;Developer, full-stack;Developer, QA or test
# idx: 12467
# value: Developer, desktop or enterprise applications;Developer, front-end;Developer, mobile
# idx: 12468
# value: Developer, front-end
# idx: 12470
# value: Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist;Engineer, site reliability
# idx: 12471
# value: Data scientist or machine learning specialist;Developer, back-end;Engineer, data
# idx: 12472
# value: Developer, desktop or enterprise applications
# idx: 12473
# value: Designer;Developer, front-end;Developer, full-stack
# idx: 12474
# value: Developer, full-stack;Developer, mobile;DevOps specialist;Educator;Engineer, site reliability
# idx: 12475
# value: Developer, back-end
# idx: 12476
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 12477
# value: Developer, back-end;Developer, mobile;Developer, QA or test
# idx: 12478
# value: Designer;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, game or graphics;Developer, mobile
# idx: 12479
# value: Developer, back-end
# idx: 12480
# value: Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist
# idx: 12481
# value: Developer, full-stack;System administrator
# idx: 12482
# value: Engineer, data
# idx: 12483
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12484
# value: Data or business analyst;Data scientist or machine learning specialist;Database administrator;Developer, back-end;Developer, full-stack;Developer, QA or test;DevOps specialist;Engineer, data
# idx: 12485
# value: Data scientist or machine learning specialist;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Engineer, data
# idx: 12486
# value: Academic researcher;Scientist
# idx: 12487
# value: Developer, embedded applications or devices
# idx: 12488
# value: Data or business analyst
# idx: 12489
# value: Developer, back-end;Developer, embedded applications or devices;Developer, full-stack;Developer, mobile
# idx: 12490
# value: Data or business analyst;Developer, full-stack;DevOps specialist
# idx: 12491
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, mobile
# idx: 12492
# value: Developer, full-stack
# idx: 12493
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile;Developer, QA or test
# idx: 12494
# value: Developer, full-stack
# idx: 12495
# value: Developer, front-end;Developer, full-stack
# idx: 12496
# value: Database administrator;Developer, back-end;Developer, embedded applications or devices;Developer, front-end
# idx: 12498
# value: Academic researcher;Developer, full-stack
# idx: 12500
# value: Database administrator;Developer, back-end
# idx: 12501
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications
# idx: 12502
# value: Academic researcher;Developer, back-end;Developer, full-stack;Developer, mobile;Educator;Product manager
# idx: 12503
# value: Developer, back-end;Developer, full-stack
# idx: 12505
# value: Developer, back-end;DevOps specialist;Engineer, site reliability
# idx: 12506
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12508
# value: Developer, back-end;Developer, desktop or enterprise applications;Engineer, data
# idx: 12509
# value: Data or business analyst;Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;System administrator
# idx: 12510
# value: Developer, mobile
# idx: 12511
# value: Data or business analyst;Developer, full-stack
# idx: 12512
# value: Developer, embedded applications or devices;Engineering manager
# idx: 12513
# value: Data scientist or machine learning specialist;Developer, back-end
# idx: 12514
# value: Developer, back-end;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12515
# value: Developer, back-end
# idx: 12517
# value: Developer, back-end;Developer, embedded applications or devices;DevOps specialist
# idx: 12518
# value: Developer, back-end
# idx: 12520
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, game or graphics
# idx: 12521
# value: Developer, back-end;Developer, full-stack;Educator
# idx: 12522
# value: Designer;Developer, front-end;Developer, mobile;Marketing or sales professional
# idx: 12524
# value: DevOps specialist
# idx: 12525
# value: Developer, back-end;Developer, front-end;Developer, game or graphics;Developer, mobile
# idx: 12526
# value: Developer, back-end
# idx: 12527
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 12528
# value: Developer, back-end;Developer, front-end
# idx: 12529
# value: Developer, front-end
# idx: 12531
# value: Developer, back-end;Developer, QA or test;DevOps specialist;Engineer, site reliability;Engineering manager
# idx: 12532
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Educator
# idx: 12533
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, QA or test;DevOps specialist
# idx: 12534
# value: Developer, full-stack
# idx: 12535
# value: Data scientist or machine learning specialist;Developer, back-end;Developer, full-stack;DevOps specialist;Engineer, data
# idx: 12536
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12537
# value: Developer, front-end;Developer, full-stack;Educator
# idx: 12538
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, game or graphics
# idx: 12539
# value: Academic researcher;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12540
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12541
# value: Developer, back-end;Developer, front-end
# idx: 12542
# value: Developer, back-end;Developer, embedded applications or devices;Developer, front-end;Developer, game or graphics;DevOps specialist
# idx: 12543
# value: Data scientist or machine learning specialist
# idx: 12544
# value: Data or business analyst
# idx: 12545
# value: Developer, full-stack
# idx: 12546
# value: Developer, back-end
# idx: 12550
# value: Developer, back-end;DevOps specialist;Engineer, site reliability;System administrator
# idx: 12551
# value: Academic researcher;Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12552
# value: Designer;Developer, full-stack;Engineering manager;Product manager
# idx: 12553
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12554
# value: Developer, back-end;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack
# idx: 12555
# value: Database administrator;System administrator
# idx: 12556
# value: Developer, QA or test
# idx: 12557
# value: Developer, back-end;Developer, full-stack;Educator;System administrator
# idx: 12558
# value: Developer, full-stack
# idx: 12559
# value: Developer, back-end;DevOps specialist;Engineer, data;Engineer, site reliability
# idx: 12560
# value: Developer, desktop or enterprise applications;Developer, front-end
# idx: 12561
# value: Designer
# idx: 12563
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 12564
# value: Developer, front-end;Developer, mobile
# idx: 12565
# value: Developer, back-end;Developer, full-stack;Educator
# idx: 12566
# value: DevOps specialist
# idx: 12567
# value: Developer, embedded applications or devices;Developer, full-stack;Developer, mobile
# idx: 12568
# value: Data or business analyst;Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile;Product manager;Senior executive/VP
# idx: 12569
# value: Developer, mobile
# idx: 12570
# value: Developer, mobile
# idx: 12572
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Engineer, data;System administrator
# idx: 12573
# value: Developer, full-stack
# idx: 12574
# value: Developer, desktop or enterprise applications;Developer, mobile
# idx: 12575
# value: Developer, front-end;Developer, full-stack
# idx: 12576
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 12577
# value: Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;Developer, back-end;DevOps specialist;System administrator
# idx: 12578
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 12579
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 12580
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack
# idx: 12581
# value: Developer, back-end;Developer, front-end
# idx: 12582
# value: Developer, back-end
# idx: 12584
# value: Developer, desktop or enterprise applications
# idx: 12585
# value: Developer, full-stack
# idx: 12586
# value: Developer, back-end
# idx: 12589
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12590
# value: Developer, front-end
# idx: 12591
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12593
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications
# idx: 12594
# value: Academic researcher;Developer, desktop or enterprise applications;Developer, mobile
# idx: 12596
# value: Developer, back-end;Developer, embedded applications or devices
# idx: 12597
# value: Developer, embedded applications or devices
# idx: 12598
# value: Database administrator;DevOps specialist;System administrator
# idx: 12599
# value: Developer, back-end;Developer, front-end
# idx: 12600
# value: Developer, back-end;Developer, front-end
# idx: 12601
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12602
# value: Developer, full-stack
# idx: 12603
# value: Data or business analyst;Data scientist or machine learning specialist;Database administrator;Developer, back-end;Educator;Engineer, data
# idx: 12604
# value: Developer, back-end;Developer, full-stack
# idx: 12605
# value: Developer, back-end;Developer, embedded applications or devices
# idx: 12607
# value: Product manager
# idx: 12610
# value: Developer, embedded applications or devices;Developer, full-stack;Engineer, data;Engineering manager;Scientist
# idx: 12611
# value: Data scientist or machine learning specialist;Engineer, site reliability
# idx: 12612
# value: Academic researcher;Developer, full-stack;DevOps specialist;Engineering manager
# idx: 12614
# value: Developer, full-stack
# idx: 12615
# value: Academic researcher;Data scientist or machine learning specialist;Developer, back-end;Developer, front-end;Developer, full-stack;System administrator
# idx: 12616
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack;Developer, game or graphics
# idx: 12617
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile
# idx: 12618
# value: Developer, full-stack
# idx: 12620
# value: Data or business analyst;Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12621
# value: Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist;System administrator
# idx: 12623
# value: Database administrator;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;System administrator
# idx: 12624
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12625
# value: Developer, full-stack
# idx: 12626
# value: Developer, back-end;Developer, full-stack
# idx: 12627
# value: Developer, back-end;DevOps specialist
# idx: 12628
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12629
# value: Designer;Developer, full-stack;Educator
# idx: 12630
# value: Developer, QA or test
# idx: 12631
# value: Designer;Developer, desktop or enterprise applications;DevOps specialist
# idx: 12632
# value: Developer, full-stack
# idx: 12633
# value: Developer, full-stack
# idx: 12634
# value: Developer, back-end;DevOps specialist;Educator
# idx: 12635
# value: Developer, desktop or enterprise applications;System administrator
# idx: 12636
# value: Developer, desktop or enterprise applications;Developer, embedded applications or devices
# idx: 12637
# value: Data or business analyst;Data scientist or machine learning specialist;Developer, embedded applications or devices;Engineering manager
# idx: 12638
# value: Developer, back-end;Developer, full-stack;Developer, QA or test;DevOps specialist
# idx: 12639
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, mobile
# idx: 12640
# value: Developer, full-stack;Developer, mobile
# idx: 12641
# value: Data or business analyst;Data scientist or machine learning specialist;Developer, full-stack
# idx: 12642
# value: Developer, back-end
# idx: 12643
# value: Developer, desktop or enterprise applications;Scientist
# idx: 12645
# value: Developer, full-stack
# idx: 12646
# value: Academic researcher;Data scientist or machine learning specialist;Engineer, data
# idx: 12647
# value: Academic researcher;Data scientist or machine learning specialist;Developer, full-stack;Educator;Engineer, data;Product manager;Scientist
# idx: 12648
# value: Developer, back-end
# idx: 12649
# value: Developer, full-stack
# idx: 12650
# value: Developer, full-stack
# idx: 12651
# value: Developer, back-end;Developer, front-end
# idx: 12652
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 12653
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Engineer, data;System administrator
# idx: 12654
# value: Developer, full-stack
# idx: 12655
# value: Developer, mobile
# idx: 12656
# value: Academic researcher
# idx: 12657
# value: Developer, back-end;DevOps specialist
# idx: 12658
# value: Developer, full-stack
# idx: 12659
# value: Academic researcher;Data scientist or machine learning specialist
# idx: 12660
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;DevOps specialist;Engineer, site reliability;System administrator
# idx: 12661
# value: Database administrator;Developer, back-end;Developer, QA or test;Engineer, site reliability;System administrator
# idx: 12662
# value: Academic researcher
# idx: 12664
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 12665
# value: Developer, back-end;Developer, embedded applications or devices;Engineering manager
# idx: 12666
# value: Developer, mobile;Educator;System administrator
# idx: 12667
# value: Developer, back-end
# idx: 12668
# value: Developer, full-stack
# idx: 12669
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12670
# value: Developer, front-end;Developer, mobile;Developer, QA or test
# idx: 12671
# value: Database administrator;Developer, back-end;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12673
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack;Developer, mobile
# idx: 12674
# value: Data scientist or machine learning specialist;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, game or graphics;Scientist
# idx: 12675
# value: Data or business analyst;Data scientist or machine learning specialist
# idx: 12676
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12678
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 12679
# value: Developer, back-end
# idx: 12680
# value: Developer, mobile
# idx: 12681
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 12682
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 12683
# value: Developer, back-end
# idx: 12686
# value: Developer, back-end;DevOps specialist
# idx: 12687
# value: Engineer, site reliability;System administrator
# idx: 12688
# value: Developer, mobile
# idx: 12689
# value: Developer, front-end
# idx: 12690
# value: Developer, full-stack
# idx: 12691
# value: Database administrator;Developer, back-end;Developer, mobile;Engineer, data;Engineering manager
# idx: 12692
# value: Developer, back-end
# idx: 12694
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics
# idx: 12695
# value: Designer;Developer, front-end;Developer, full-stack
# idx: 12697
# value: Developer, back-end;Developer, mobile
# idx: 12698
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 12699
# value: Academic researcher;Developer, full-stack;Scientist
# idx: 12700
# value: Developer, desktop or enterprise applications
# idx: 12701
# value: Data scientist or machine learning specialist;Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist;System administrator
# idx: 12702
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, mobile
# idx: 12703
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12704
# value: Developer, front-end
# idx: 12705
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, game or graphics;DevOps specialist;Engineer, site reliability
# idx: 12706
# value: Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile;DevOps specialist;System administrator
# idx: 12707
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 12708
# value: Data scientist or machine learning specialist;Developer, full-stack
# idx: 12709
# value: Developer, front-end;Developer, full-stack;Engineering manager
# idx: 12710
# value: Developer, full-stack
# idx: 12711
# value: Developer, full-stack
# idx: 12712
# value: Developer, full-stack;Developer, mobile
# idx: 12713
# value: Developer, back-end;Developer, full-stack;DevOps specialist;Engineer, site reliability
# idx: 12714
# value: Developer, full-stack;DevOps specialist
# idx: 12715
# value: Data or business analyst
# idx: 12716
# value: Developer, back-end;Developer, full-stack
# idx: 12717
# value: Data or business analyst;Developer, back-end;Developer, embedded applications or devices;Developer, full-stack;Developer, mobile
# idx: 12718
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;System administrator
# idx: 12719
# value: Developer, full-stack
# idx: 12720
# value: Developer, back-end;Developer, front-end
# idx: 12721
# value: Developer, front-end
# idx: 12722
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12723
# value: Developer, game or graphics;Developer, mobile
# idx: 12724
# value: Developer, mobile
# idx: 12725
# value: Developer, desktop or enterprise applications;System administrator
# idx: 12726
# value: Data or business analyst;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;System administrator
# idx: 12728
# value: Data or business analyst;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 12729
# value: Developer, full-stack;DevOps specialist
# idx: 12731
# value: Engineer, data
# idx: 12733
# value: Developer, back-end;Engineer, data
# idx: 12734
# value: Developer, back-end
# idx: 12735
# value: Developer, back-end;Developer, embedded applications or devices;Product manager
# idx: 12736
# value: Designer;Developer, back-end;Developer, front-end
# idx: 12737
# value: Academic researcher;Educator
# idx: 12740
# value: Developer, back-end
# idx: 12741
# value: Developer, back-end;Developer, game or graphics;Engineer, site reliability
# idx: 12742
# value: Developer, front-end
# idx: 12743
# value: Developer, back-end
# idx: 12744
# value: Developer, back-end;Developer, full-stack;Developer, QA or test
# idx: 12745
# value: Developer, back-end;Developer, embedded applications or devices;Developer, full-stack
# idx: 12746
# value: Data or business analyst;Developer, back-end;Developer, embedded applications or devices;Developer, mobile
# idx: 12747
# value: Developer, back-end;Developer, full-stack;Educator;System administrator
# idx: 12748
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;DevOps specialist;System administrator
# idx: 12749
# value: Developer, front-end
# idx: 12750
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 12752
# value: Developer, back-end;Developer, embedded applications or devices;Developer, full-stack
# idx: 12753
# value: Developer, full-stack
# idx: 12754
# value: Database administrator;Developer, back-end;DevOps specialist;System administrator
# idx: 12755
# value: Developer, full-stack
# idx: 12756
# value: Developer, back-end
# idx: 12757
# value: Developer, back-end;Developer, full-stack;Educator
# idx: 12758
# value: Data or business analyst;Database administrator;Developer, back-end;Developer, full-stack
# idx: 12759
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12760
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12761
# value: Marketing or sales professional
# idx: 12762
# value: Academic researcher;Data or business analyst
# idx: 12763
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12765
# value: Academic researcher;Educator
# idx: 12767
# value: Developer, desktop or enterprise applications
# idx: 12771
# value: Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist;Engineer, site reliability
# idx: 12773
# value: Developer, back-end
# idx: 12774
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, mobile;Developer, QA or test
# idx: 12775
# value: Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, full-stack;Developer, mobile;Engineer, site reliability
# idx: 12776
# value: Developer, back-end
# idx: 12777
# value: Developer, back-end
# idx: 12778
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 12779
# value: Developer, back-end
# idx: 12780
# value: Developer, full-stack
# idx: 12782
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12783
# value: Developer, back-end;Developer, full-stack
# idx: 12784
# value: Data scientist or machine learning specialist;Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 12785
# value: Developer, full-stack;DevOps specialist
# idx: 12788
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 12789
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12790
# value: Data scientist or machine learning specialist
# idx: 12791
# value: Developer, back-end
# idx: 12792
# value: Developer, full-stack
# idx: 12793
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12794
# value: Developer, back-end;Developer, mobile;Educator
# idx: 12796
# value: Developer, back-end;Developer, full-stack
# idx: 12797
# value: Developer, full-stack
# idx: 12799
# value: Developer, QA or test
# idx: 12800
# value: Developer, full-stack
# idx: 12801
# value: Developer, full-stack
# idx: 12802
# value: Developer, back-end
# idx: 12803
# value: Developer, front-end
# idx: 12804
# value: Developer, back-end;Developer, front-end
# idx: 12805
# value: Developer, full-stack
# idx: 12806
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, game or graphics;Developer, QA or test
# idx: 12807
# value: Data or business analyst;Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile;Product manager;System administrator
# idx: 12809
# value: Developer, embedded applications or devices;Engineering manager;Product manager
# idx: 12811
# value: Academic researcher
# idx: 12812
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 12813
# value: Academic researcher;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12814
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;DevOps specialist;System administrator
# idx: 12815
# value: Developer, desktop or enterprise applications;Developer, full-stack;Engineer, data
# idx: 12816
# value: Developer, back-end;Developer, full-stack
# idx: 12817
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile
# idx: 12818
# value: Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack;DevOps specialist
# idx: 12819
# value: Developer, back-end;Developer, full-stack
# idx: 12820
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end
# idx: 12821
# value: Developer, full-stack
# idx: 12822
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 12823
# value: Developer, front-end
# idx: 12824
# value: Academic researcher;Data or business analyst;Educator
# idx: 12825
# value: Marketing or sales professional
# idx: 12826
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12827
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12828
# value: Developer, mobile
# idx: 12829
# value: Developer, back-end;DevOps specialist
# idx: 12830
# value: Developer, front-end;Developer, full-stack
# idx: 12831
# value: Developer, mobile;Educator
# idx: 12832
# value: Developer, mobile
# idx: 12833
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;System administrator
# idx: 12834
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 12835
# value: Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist
# idx: 12836
# value: Developer, desktop or enterprise applications
# idx: 12837
# value: Developer, front-end
# idx: 12838
# value: Developer, full-stack
# idx: 12839
# value: Academic researcher;Developer, front-end;Developer, full-stack;Developer, QA or test;DevOps specialist
# idx: 12840
# value: Developer, front-end;Developer, full-stack
# idx: 12841
# value: Academic researcher;Data scientist or machine learning specialist;Database administrator;Educator;Scientist
# idx: 12842
# value: Database administrator;Developer, full-stack;DevOps specialist;Engineer, site reliability;System administrator
# idx: 12843
# value: DevOps specialist
# idx: 12845
# value: Developer, back-end;Developer, mobile;Educator;Product manager
# idx: 12846
# value: Data or business analyst;Developer, back-end;Developer, full-stack;DevOps specialist
# idx: 12848
# value: Developer, full-stack;Developer, mobile;Product manager;Senior executive/VP
# idx: 12849
# value: Data or business analyst;Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;System administrator
# idx: 12850
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12851
# value: Developer, back-end;Developer, full-stack
# idx: 12852
# value: Developer, mobile
# idx: 12854
# value: Academic researcher;Data scientist or machine learning specialist;Scientist
# idx: 12855
# value: Developer, back-end
# idx: 12856
# value: Developer, back-end
# idx: 12857
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, mobile
# idx: 12858
# value: Data scientist or machine learning specialist;Engineer, data
# idx: 12859
# value: DevOps specialist
# idx: 12860
# value: Developer, back-end;Developer, mobile
# idx: 12861
# value: Developer, mobile
# idx: 12864
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, QA or test;DevOps specialist;Educator
# idx: 12865
# value: System administrator
# idx: 12866
# value: Developer, back-end
# idx: 12867
# value: Data or business analyst;Developer, back-end;Developer, full-stack;DevOps specialist;Engineer, data;Engineer, site reliability;System administrator
# idx: 12868
# value: Database administrator;Developer, back-end;Developer, full-stack
# idx: 12869
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, QA or test
# idx: 12870
# value: Designer;Developer, front-end
# idx: 12871
# value: Developer, back-end;Developer, full-stack
# idx: 12872
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end
# idx: 12873
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile;Engineer, site reliability;Engineering manager
# idx: 12874
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile;System administrator
# idx: 12875
# value: Developer, full-stack
# idx: 12876
# value: Data scientist or machine learning specialist;Developer, back-end;Developer, full-stack;Engineer, data
# idx: 12877
# value: Developer, back-end;Developer, front-end
# idx: 12878
# value: Developer, back-end;Developer, full-stack
# idx: 12879
# value: Developer, full-stack
# idx: 12880
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12881
# value: Developer, mobile
# idx: 12882
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 12884
# value: Developer, back-end
# idx: 12885
# value: Database administrator;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;System administrator
# idx: 12886
# value: Developer, desktop or enterprise applications;Scientist
# idx: 12887
# value: Developer, front-end
# idx: 12888
# value: Developer, front-end;Developer, full-stack
# idx: 12889
# value: Developer, full-stack;Developer, mobile
# idx: 12890
# value: Designer;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile;Educator
# idx: 12891
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices
# idx: 12892
# value: Developer, back-end;Engineer, data
# idx: 12893
# value: Developer, back-end;Developer, front-end;Developer, full-stack;System administrator
# idx: 12895
# value: Developer, front-end;Developer, full-stack
# idx: 12896
# value: Database administrator;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, QA or test;DevOps specialist
# idx: 12897
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12899
# value: Developer, front-end
# idx: 12900
# value: Developer, back-end;Developer, full-stack
# idx: 12901
# value: Developer, front-end
# idx: 12902
# value: Designer;Developer, front-end
# idx: 12903
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 12905
# value: Developer, mobile
# idx: 12906
# value: Developer, back-end;Developer, full-stack
# idx: 12907
# value: Academic researcher;Developer, back-end;Developer, front-end;Developer, full-stack;Educator
# idx: 12908
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile;Engineer, data
# idx: 12909
# value: Developer, full-stack
# idx: 12910
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 12911
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 12912
# value: Academic researcher
# idx: 12913
# value: Database administrator;Designer;Developer, desktop or enterprise applications;Developer, full-stack;Developer, game or graphics
# idx: 12914
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 12915
# value: Developer, back-end;Engineer, data
# idx: 12916
# value: Developer, back-end
# idx: 12917
# value: Developer, full-stack
# idx: 12918
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;DevOps specialist;Marketing or sales professional
# ...
# value: Database administrator;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;System administrator
# idx: 15011
# value: Data scientist or machine learning specialist;Developer, back-end
# idx: 15012
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 15013
# value: Developer, full-stack;Engineering manager
# idx: 15014
# value: Database administrator;Developer, back-end;Developer, full-stack;DevOps specialist;Product manager;System administrator
# idx: 15015
# value: Data scientist or machine learning specialist;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 15016
# value: Developer, full-stack
# idx: 15017
# value: Data or business analyst;Product manager
# idx: 15018
# value: Academic researcher;Developer, desktop or enterprise applications
# idx: 15019
# value: Developer, front-end;Developer, full-stack;DevOps specialist
# idx: 15020
# value: Developer, back-end
# idx: 15021
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 15022
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Scientist
# idx: 15023
# value: Designer;Developer, front-end;Product manager
# idx: 15024
# value: Designer;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile;DevOps specialist;Engineering manager
# idx: 15026
# value: Designer;Developer, front-end;Developer, full-stack
# idx: 15027
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 15028
# value: Developer, full-stack;Developer, mobile
# idx: 15029
# value: Developer, full-stack
# idx: 15030
# value: Academic researcher;Data scientist or machine learning specialist;Developer, desktop or enterprise applications;Engineer, data
# idx: 15031
# value: Developer, front-end
# idx: 15033
# value: Database administrator;Developer, back-end;Developer, full-stack;DevOps specialist
# idx: 15034
# value: Designer;Developer, front-end;Developer, full-stack;DevOps specialist
# idx: 15035
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, game or graphics;DevOps specialist
# idx: 15036
# value: Developer, mobile
# idx: 15037
# value: Developer, back-end;Developer, QA or test
# idx: 15038
# value: Developer, game or graphics;Developer, mobile
# idx: 15040
# value: Data scientist or machine learning specialist;Developer, back-end
# idx: 15041
# value: Developer, back-end
# idx: 15042
# value: Data or business analyst;Database administrator;Developer, desktop or enterprise applications;Developer, front-end
# idx: 15043
# value: Designer;Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist
# idx: 15044
# value: Data or business analyst;Data scientist or machine learning specialist;Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;DevOps specialist;System administrator
# idx: 15045
# value: Developer, full-stack
# idx: 15046
# value: Developer, embedded applications or devices;Developer, front-end;Developer, game or graphics
# idx: 15047
# value: Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist
# idx: 15049
# value: Designer;Developer, full-stack
# idx: 15050
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile;Developer, QA or test;Product manager;System administrator
# idx: 15051
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 15052
# value: Academic researcher;Data scientist or machine learning specialist;Developer, full-stack;Developer, game or graphics;Scientist
# idx: 15053
# value: Developer, front-end;Developer, full-stack;Developer, QA or test
# idx: 15054
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, QA or test
# idx: 15055
# value: Database administrator;Designer;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Product manager
# idx: 15056
# value: Designer;Developer, front-end;Developer, full-stack
# idx: 15057
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, mobile;DevOps specialist;Engineer, site reliability;Marketing or sales professional;Scientist;Senior executive/VP;System administrator
# idx: 15058
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile;System administrator
# idx: 15060
# value: Academic researcher;Data or business analyst;Data scientist or machine learning specialist;Developer, back-end;Developer, full-stack;Scientist
# idx: 15061
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 15062
# value: Developer, back-end;Developer, full-stack
# idx: 15063
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 15064
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 15065
# value: Developer, back-end;Developer, full-stack
# idx: 15066
# value: Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Developer, QA or test
# idx: 15067
# value: Academic researcher;Data scientist or machine learning specialist;Engineering manager
# idx: 15068
# value: Developer, full-stack;Developer, game or graphics;Scientist
# idx: 15070
# value: Designer;Developer, front-end;Developer, game or graphics;Developer, mobile
# idx: 15071
# value: Developer, back-end
# idx: 15072
# value: Academic researcher;Data scientist or machine learning specialist;Database administrator;Designer;Developer, back-end;Developer, embedded applications or devices;Developer, front-end;Developer, mobile;Developer, QA or test;Educator;Scientist;System administrator
# idx: 15073
# value: Developer, back-end;Developer, front-end;Developer, game or graphics;Developer, mobile;Developer, QA or test
# idx: 15074
# value: Developer, full-stack
# idx: 15075
# value: Engineer, data;Engineer, site reliability;Scientist
# idx: 15076
# value: Developer, front-end;Developer, full-stack
# idx: 15077
# value: Developer, embedded applications or devices
# idx: 15078
# value: Developer, full-stack;Developer, QA or test
# idx: 15079
# value: Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Educator
# idx: 15080
# value: Developer, front-end;Developer, mobile
# idx: 15081
# value: Developer, front-end
# idx: 15083
# value: Developer, desktop or enterprise applications;Developer, embedded applications or devices;System administrator
# idx: 15084
# value: Developer, full-stack
# idx: 15085
# value: Developer, front-end
# idx: 15086
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 15087
# value: Developer, back-end
# idx: 15088
# value: Product manager;Senior executive/VP
# idx: 15089
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices
# idx: 15090
# value: Developer, back-end;Developer, full-stack
# idx: 15091
# value: Developer, full-stack
# idx: 15092
# value: Developer, full-stack
# idx: 15094
# value: Database administrator;Developer, full-stack;Developer, mobile;Developer, QA or test;DevOps specialist;Engineer, site reliability
# idx: 15095
# value: Developer, back-end
# idx: 15096
# value: Data scientist or machine learning specialist;Developer, back-end
# idx: 15097
# value: Developer, back-end;Developer, full-stack;DevOps specialist
# idx: 15099
# value: Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 15100
# value: Developer, full-stack
# idx: 15101
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications
# idx: 15102
# value: Developer, full-stack
# idx: 15103
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 15104
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 15105
# value: Data or business analyst;Designer;Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist;System administrator
# idx: 15106
# value: Developer, full-stack
# idx: 15108
# value: Developer, front-end;Developer, full-stack
# idx: 15109
# value: Data scientist or machine learning specialist;Developer, back-end;Developer, full-stack;Engineer, data
# idx: 15110
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 15113
# value: Developer, back-end;Developer, full-stack;Developer, mobile
# idx: 15114
# value: Developer, desktop or enterprise applications
# idx: 15115
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 15116
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 15117
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 15119
# value: Data scientist or machine learning specialist;Developer, embedded applications or devices
# idx: 15120
# value: Academic researcher;Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 15121
# value: Designer;Developer, back-end;Developer, full-stack;Developer, mobile
# idx: 15122
# value: Developer, front-end;Developer, full-stack;Engineering manager
# idx: 15123
# value: Developer, back-end
# idx: 15124
# value: Data or business analyst;Data scientist or machine learning specialist
# idx: 15125
# value: Developer, embedded applications or devices;Developer, full-stack
# idx: 15126
# value: Developer, back-end
# idx: 15127
# value: Developer, full-stack
# idx: 15128
# value: Academic researcher;Database administrator;Developer, full-stack;Educator
# idx: 15129
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile;Developer, QA or test
# idx: 15130
# value: Developer, full-stack
# idx: 15131
# value: Data scientist or machine learning specialist;Scientist
# idx: 15132
# value: Developer, back-end
# idx: 15134
# value: Developer, back-end
# idx: 15135
# value: Developer, back-end
# idx: 15136
# value: Developer, embedded applications or devices;Developer, mobile;Engineering manager
# idx: 15137
# value: Developer, back-end;Scientist;System administrator
# idx: 15139
# value: Designer;Developer, embedded applications or devices;Engineer, site reliability
# idx: 15141
# value: Senior executive/VP
# idx: 15142
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end
# idx: 15143
# value: Developer, front-end;Developer, game or graphics;Developer, mobile
# idx: 15144
# value: Developer, full-stack
# idx: 15145
# value: Developer, desktop or enterprise applications;Developer, full-stack;DevOps specialist;Engineer, site reliability;Engineering manager;System administrator
# idx: 15146
# value: Developer, back-end;Developer, full-stack;Developer, mobile
# idx: 15147
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Developer, mobile;Developer, QA or test
# idx: 15148
# value: Data scientist or machine learning specialist;Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 15149
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile;Product manager;Senior executive/VP
# idx: 15150
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 15151
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Engineer, data;Engineering manager;Senior executive/VP
# idx: 15152
# value: Developer, full-stack
# idx: 15153
# value: Developer, back-end;Developer, full-stack;Developer, mobile
# idx: 15154
# value: Developer, front-end
# idx: 15155
# value: Academic researcher;Data scientist or machine learning specialist;Educator;Scientist
# idx: 15156
# value: Developer, full-stack;Developer, mobile;System administrator
# idx: 15157
# value: Developer, back-end;Developer, full-stack
# idx: 15158
# value: Developer, full-stack
# idx: 15159
# value: Academic researcher;Data scientist or machine learning specialist;Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Educator;Engineer, data;Engineer, site reliability;System administrator
# idx: 15160
# value: Developer, full-stack
# idx: 15163
# value: Developer, full-stack;Developer, mobile
# idx: 15166
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end
# idx: 15167
# value: Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 15168
# value: Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, mobile
# idx: 15169
# value: Developer, back-end
# idx: 15170
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, full-stack
# idx: 15171
# value: Developer, back-end;Developer, QA or test
# idx: 15172
# value: Database administrator;Developer, back-end;Developer, full-stack;DevOps specialist;Engineer, site reliability;System administrator
# idx: 15173
# value: Developer, back-end
# idx: 15174
# value: Developer, embedded applications or devices;Developer, front-end;Product manager
# idx: 15176
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 15177
# value: Designer;Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist
# idx: 15178
# value: Developer, back-end;DevOps specialist;Engineer, site reliability
# idx: 15179
# value: Developer, full-stack;Senior executive/VP
# idx: 15181
# value: Developer, back-end;Developer, front-end;Developer, full-stack;DevOps specialist
# idx: 15182
# value: Academic researcher;Data scientist or machine learning specialist;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices
# idx: 15183
# value: Developer, back-end;Developer, desktop or enterprise applications
# idx: 15185
# value: Developer, full-stack;Developer, mobile;Engineering manager
# idx: 15186
# value: Developer, full-stack
# idx: 15187
# value: DevOps specialist;Engineering manager
# idx: 15188
# value: Developer, back-end
# idx: 15189
# value: Developer, back-end;Developer, front-end;Developer, full-stack
# idx: 15190
# value: Developer, back-end;Developer, front-end;Developer, full-stack;Educator;Product manager
# idx: 15191
# value: Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, full-stack;DevOps specialist
# idx: 15192
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack
# idx: 15193
# value: Academic researcher;Data or business analyst;Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack;Developer, QA or test;DevOps specialist;Engineering manager;Marketing or sales professional;Product manager;Senior executive/VP
# idx: 15194
# value: Academic researcher;Data scientist or machine learning specialist;Database administrator;Developer, back-end;Developer, front-end;Developer, full-stack;Scientist
# idx: 15196
# value: Developer, back-end;DevOps specialist;Engineer, site reliability
# idx: 15197
# value: Developer, full-stack
# idx: 15199
# value: Developer, back-end
# idx: 15200
# value: Developer, back-end;Developer, full-stack
# idx: 15201
# value: Developer, full-stack
# idx: 15202
# value: Developer, full-stack
# idx: 15203
# value: Database administrator;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;System administrator
# idx: 15205

# %%
dev_type_df

# %% [markdown]
# The `dev_type_df` has one column for each option that can be selected as a response. If a respondent has chosen an option, the corresponding column's value is `True`. Otherwise, it is `False`.
#
# We can now use the column-wise totals to identify the most common roles.

# %%
dev_type_totals = dev_type_df.sum().sort_values(ascending=False)
dev_type_totals

# %% [markdown]
# As one might expect, the most common roles include "Developer" in the name.
#
# **Exercises**:
#
# * Can you figure out what percentage of respondents work in roles related to data science?
# * Which positions have the highest percentage of women?

# %% [markdown]
# We've only explored a handful of columns from the 20 columns that we selected. Explore and visualize the remaining columns using the empty cells below.

# %% [markdown]
# Let's save and upload our work before continuing.

# %%
import jovian

# %%
jovian.commit()

# %% [markdown]
# ## Asking and Answering Questions
#
# We've already gained several insights about the respondents and the programming community by exploring individual columns of the dataset. Let's ask some specific questions and try to answer them using data frame operations and visualizations.

# %% [markdown]
# #### Q: What are the most popular programming languages in 2020?
#
# To answer, this we can use the `LanguageWorkedWith` column. Similar to `DevType`, respondents were allowed to choose multiple options here.

# %%
survey_df.LanguageWorkedWith

# %% [markdown]
# First, we'll split this column into a data frame containing a column of each language listed in the options.

# %%
languages_worked_df = split_multicolumn(survey_df.LanguageWorkedWith)

# %%
languages_worked_df

# %% [markdown]
# It appears that a total of 25 languages were included among the options. Let's aggregate these to identify the percentage of respondents who selected each language.

# %%
languages_worked_percentages = languages_worked_df.mean().sort_values(ascending=False) * 100
languages_worked_percentages

# %% [markdown]
# We can plot this information using a horizontal bar chart.

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=languages_worked_percentages, y=languages_worked_percentages.index)
plt.title("Languages used in the past year");
plt.xlabel('count');

# %% [markdown]
# Perhaps unsurprisingly, Javascript & HTML/CSS comes out at the top as web development is one of today's most sought skills. It also happens to be one of the easiest to get started. SQL is necessary for working with relational databases, so it's no surprise that most programmers work with SQL regularly. Python seems to be the popular choice for other forms of development, beating out Java, which was the industry standard for server & application development for over two decades.
#
# **Exercises**:
#
# * What are the most common languages used by students? How does the list compare with the most common languages used by professional developers?
# * What are the most common languages among respondents who do not describe themselves as "Developer, front-end"?
# * What are the most common languages among respondents who work in fields related to data science?
# * What are the most common languages used by developers older than 35 years of age?
# * What are the most common languages used by developers in your home country?

# %% [markdown]
# #### Q: Which languages are the most people interested to learn over the next year?
#
# For this, we can use the `LanguageDesireNextYear` column, with similar processing as the previous one.

# %%
languages_interested_df = split_multicolumn(survey_df.LanguageDesireNextYear)
languages_interested_percentages = languages_interested_df.mean().sort_values(ascending=False) * 100
languages_interested_percentages

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=languages_interested_percentages, y=languages_interested_percentages.index)
plt.title("Languages people are intersted in learning over the next year");
plt.xlabel('count');

# %% [markdown]
# Once again, it's not surprising that Python is the language most people are interested in learning - since it is an easy-to-learn general-purpose programming language well suited for a variety of domains: application development, numerical computing, data analysis, machine learning, big data, cloud automation, web scraping, scripting, etc. We're using Python for this very analysis, so we're in good company!
#
# **Exercises**: Repeat the exercises from the previous question, replacing "most common languages" with "languages people are interested in learning/using."

# %% [markdown]
# #### Q:  Which are the most loved languages, i.e., a high percentage of people who have used the language want to continue learning & using it over the next year?
#
# While this question may seem tricky at first, it's straightforward to solve using Pandas array operations. Here's what we can do:
#
# - Create a new data frame `languages_loved_df` that contains a `True` value for a language only if the corresponding values in `languages_worked_df` and `languages_interested_df` are both `True`
# - Take the column-wise sum of `languages_loved_df` and divide it by the column-wise sum of `languages_worked_df` to get the percentage of respondents who "love" the language
# - Sort the results in decreasing order and plot a horizontal bar graph

# %%
languages_loved_df = languages_worked_df & languages_interested_df

# %%
languages_loved_percentages = (languages_loved_df.sum() * 100/ languages_worked_df.sum()).sort_values(ascending=False)

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=languages_loved_percentages, y=languages_loved_percentages.index)
plt.title("Most loved languages");
plt.xlabel('count');

# %% [markdown]
# [Rust](https://www.rust-lang.org) has been StackOverflow's most-loved language for [four years in a row](https://stackoverflow.blog/2020/01/20/what-is-rust-and-why-is-it-so-popular/). The second most-loved language is TypeScript, a popular alternative to JavaScript for web development.
#
# Python features at number 3, despite already being one of the most widely-used languages in the world. Python has a solid foundation, is easy to learn & use, has a large ecosystem of domain-specific libraries, and a massive worldwide community.
#
# **Exercises:** What are the most dreaded languages, i.e., languages which people have used in the past year but do not want to learn/use over the next year. Hint: `~languages_interested_df`.

# %% [markdown]
# #### Q: In which countries do developers work the highest number of hours per week? Consider countries with more than 250 responses only.
#
# To answer this question, we'll need to use the `groupby` data frame method to aggregate the rows for each country. We'll also need to filter the results to only include the countries with more than 250 respondents.

# %%
countries_df = survey_df.groupby('Country')[['WorkWeekHrs']].mean().sort_values('WorkWeekHrs', ascending=False)

# %%
high_response_countries_df = countries_df.loc[survey_df.Country.value_counts() > 250].head(15)

# %%
high_response_countries_df

# %% [markdown]
# The Asian countries like Iran, China, and Israel have the highest working hours, followed by the United States. However, there isn't too much variation overall, and the average working hours seem to be around 40 hours per week.
#
# **Exercises:**
#
# * How do the average work hours compare across continents? You may find this list of [countries in each continent](https://hub.jovian.ml/wp-content/uploads/2020/09/countries.csv) useful.
# * Which role has the highest average number of hours worked per week? Which one has the lowest?
# * How do the hours worked compare between freelancers and developers working full-time?

# %% [markdown]
# #### Q: How important is it to start young to build a career in programming?
#
# Let's create a scatter plot of `Age` vs. `YearsCodePro` (i.e., years of coding experience) to answer this question.

# %%
schema.YearsCodePro

# %%
sns.scatterplot(x='Age', y='YearsCodePro', hue='Hobbyist', data=survey_df)
plt.xlabel("Age")
plt.ylabel("Years of professional coding experience");

# %% [markdown]
# You can see points all over the graph, which indicates that you can **start programming professionally at any age**. Many people who have been coding for several decades professionally also seem to enjoy it as a hobby.
#
# We can also view the distribution of the `Age1stCode` column to see when the respondents tried programming for the first time.

# %%
plt.title(schema.Age1stCode)
sns.histplot(x=survey_df.Age1stCode, bins=30, kde=True);

# %% [markdown]
# As you might expect, most people seem to have had some exposure to programming before the age of 40. However, but there are people of all ages and walks of life learning to code.
#
# **Exercises**:
#
# * How does programming experience change opinions & preferences? Repeat the entire analysis while comparing the responses of people who have more than ten years of professional programming experience vs. those who don't. Do you see any interesting trends?
# * Compare the years of professional coding experience across different genders.

# %% [markdown]
# Hopefully, you are already thinking of many more questions you'd like to answer using this data. Use the empty cells below to ask and answer more questions.

# %% [markdown]
# Let's save and commit our work before continuing

# %%
import jovian

# %%
jovian.commit()

# %% [markdown]
# ## Inferences and Conclusions
#
# We've drawn many inferences from the survey. Here's a summary of a few of them:
#
# - Based on the survey respondents' demographics, we can infer that the survey is somewhat representative of the overall programming community. However, it has fewer responses from programmers in non-English-speaking countries and women & non-binary genders.
#
# - The programming community is not as diverse as it can be. Although things are improving, we should make more efforts to support & encourage underrepresented communities, whether in terms of age, country, race, gender, or otherwise.
#
#
# - Although most programmers hold a college degree, a reasonably large percentage did not have computer science as their college major. Hence, a computer science degree isn't compulsory for learning to code or building a career in programming.
#
# - A significant percentage of programmers either work part-time or as freelancers, which can be a great way to break into the field, especially when you're just getting started.
#
# - Javascript & HTML/CSS are the most used programming languages in 2020, closely followed by SQL & Python.
#
# - Python is the language most people are interested in learning - since it is an easy-to-learn general-purpose programming language well suited for various domains.
#
# - Rust and TypeScript are the most "loved" languages in 2020, both of which have small but fast-growing communities. Python is a close third, despite already being a widely used language.
#
# - Programmers worldwide seem to be working for around 40 hours a week on average, with slight variations by country.
#
# - You can learn and start programming professionally at any age. You're likely to have a long and fulfilling career if you also enjoy programming as a hobby.

# %% [markdown]
# ## Exercises
#
# There's a wealth of information to be discovered using the survey, and we've barely scratched the surface. Here are some ideas for further exploration:
#
# - Repeat the analysis for different age groups & genders, and compare the results
# - Pick a different set of columns (we chose 20 out of 65) to analyze other facets of the data
# - Prepare an analysis focusing on diversity - and identify areas where underrepresented communities are at par with the majority (e.g., education) and where they aren't (e.g., salaries)
# - Compare the results of this year's survey with the previous years and identify interesting trends

# %% [markdown]
# ## References and Future Work
#
# Check out the following resources to learn more about the dataset and tools used in this notebook:
#
# - Stack Overflow Developer Survey: https://insights.stackoverflow.com/survey
# - Pandas user guide: https://pandas.pydata.org/docs/user_guide/index.html
# - Matplotlib user guide: https://matplotlib.org/3.3.1/users/index.html
# - Seaborn user guide & tutorial: https://seaborn.pydata.org/tutorial.html
# - `opendatasets` Python library: https://github.com/JovianML/opendatasets
#
# As a next step, you can try out a project on another dataset of your choice: https://jovian.ml/aakashns/zerotopandas-course-project-starter .

# %%
import jovian

# %%
jovian.commit()
